# %%
import folium
import pandas as pd
from folium import plugins

# create map of British Columbia using latitude and longitude values
map_bc = folium.Map(location=[53.7267, -127.6476], zoom_start=5)

map_bc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import seaborn as sns

# Read in the data by selecting certain columns
df = pd.read_csv('bc_ghg_emissions_by_ipcc_sector_1990-2018.csv', usecols=range(5, 21))
# Drop any rows that have missing values
df = df.dropna()

# Set the year column as the x-axis values
x = df['year']

# Plot the data as a line plot with the year column as the x-axis
sns.lineplot(x=x, y='total_emissions_excluding_lulucf', data=df)
# Out:
# Index(['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns

# Read in the data by selecting certain columns
df = pd.read_csv('bc_ghg_emissions_by_ipcc_sector_1990-2018.csv')
# Drop any rows that have missing values
df = df.dropna()

# Plot the data as a line plot with the year column as the x-axis
sns.lineplot(data=df)

# print what the data in the plot is showing
print('The data in the plot shows the total emissions of BC from 1990 to 2018.')
# Out:
# The data in the plot shows the total emissions of BC from 1990 to 2018.
